# %%
#%load_ext autoreload
#%autoreload 2
# %pylab inline
from twobodyorbit import *
time, posx, velx, posy, vely = integrate_pendulum(n_steps,pendulum_linear_runge_kutta4)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# x position:
# [  0.00000000e+00  -4.15205831e-05  -8.30411662e-05  -1.24561749e-04
#   -1.66082332e-04  -2.07602915e-04  -2.49123498e-04  -2.90644082e-04
#   -3.32164665e-04  -3.73685248e-04  -4.15205831e-04  -4.56726414e-04
#   -4.98246997e-04  -5.39767580e-04  -5.81288163e-04  -6.22808746e-04
#   -6.64329329e-04  -7.05849912e-04  -7.47370495e-04  -7.88891079e-04
#   -8.30411662e-04  -8.71932245e-04  -9.13452828e-04  -9.54973411e-04
#   -9.96493994e-04  -1.03801458e-03  -1.07953516e-03  -1.12105574e-03
#   -1.16257633e-03  -1.20409691e-03  -1.24561749e-03  -1.28713808e-03
#   -1.32865866e-03  -1.37017924e-03  -1.41169982e-03  -1.45322041e-03
#   -1.49474099e-03  -1.53626157e-03  -1.57778216e-03  -1.61930274e-03
#   -1.66082332e-03  -1.70234391e-03  -1.74386449e-03  -1.78538507e-03
#   -1.82690566e-03  -1.86842624e-03  -1.90994682e-03  -1.95146740e-03
# ...

# %%
# Plot up the analytical solution to the motion
plot(time,velx, linestyle='none', marker='d')  

# Set up labels for plot
xlabel("x position")
ylabel("y position")
title("Orbit trajectory")
